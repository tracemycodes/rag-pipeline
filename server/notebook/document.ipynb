# %% [markdown]
# ### Data Ingestion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"source": "example.txt", "author": "John Doe"},
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'John Doe'}, page_content='This is the content of the document.')

# %%
### Create a simple txt file

import os

os.makedirs("../data/text_files", exist_ok=True)

# %%
 
sample_texts={
     "../data/text_files/python_intro.txt": """lorem20 ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.""",
 }
 
 
for file_path, content in sample_texts.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)
        
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader


loader = TextLoader("../data/text_files/python_intro.txt")

documents = loader.load()

documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='lorem20 ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.')]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

## Load all text files in the directory
directory_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)

documents=directory_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='lorem20 ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.')]

# %%
### Directory Loader

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## Load all PDF files in the directory
directory_loader = DirectoryLoader(
    "../data/pdf", 
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=False
)

pdf_documents=directory_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-06T21:48:31+00:00', 'title': 'Mentalyc Cheatsheets', 'moddate': '2024-07-06T21:48:30+00:00', 'keywords': 'DAGJDqOdZO0,BAFXld6g6w4', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/iStatementWorksheet.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='"I" Statements \nWorksheet\nMentalyc IncExplore Secure AI-Powered Progress Note Automation!\n"I" statements are a form of assertive communication that express your thoughts,\nfeelings, and needs in a clear and respectful manner. They focus on personal\nexperiences and avoid blaming or accusing others.\nWhy Use "I" Statements?\n"I" statements help you express emotions in a direct and non-confrontational\nmanner.\nUsing "I" statements enhances mutual understanding and promotes active\nlistening.\nThey minimize defensiveness and prevent others from feeling attacked.\n"I" statements contribute to open, respectful communication, fostering positive\nrelationships.\n"You never listen to me when I talk about my feelings."\nExamples of Blaming vs. "I" Statements\nBlaming Statement\n"I" Statement "I feel frustrated when I don\'t feel heard when talking\nabout my feelings."\nBlaming Statement "You always leave the dishes in the sink for me to\nclean up."\n"I" Statement "I feel overwhelmed when I see dishes in the sink after\na long day."\n"I" Statement Practice:\nPractice Section: Scenario vs. "I" Statements\nScenario 1:\nScenario: Your colleague frequently arrives late to team meetings, causing delays\nand frustration among team members.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-06T21:48:31+00:00', 'title': 'Mentalyc Cheatsheets', 'moddate': '2024-07-06T21:48:30+00:00', 'keywords': 'DAGJDqOdZO0,BAFXld6g6w4', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/iStatementWorksheet.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='"I" Statements \nWorksheet\nMentalyc IncCreated by www.mentalyc.com\n"I" Statement Practice:\nPractice Section: Scenario vs. "I" Statements\nScenario 2:\nScenario: Your partner forgets to pick up groceries after you specifically asked\nthem to do so.\n"I" Statement Practice:\nScenario 3:\nScenario: Your roommate consistently leaves dirty dishes in the sink.\n"I" Statement Practice:\nScenario 4:\nScenario: Your friend frequently borrows your belongings without asking and often\nreturns them damaged or late.\n"I" Statement Practice:\nScenario 5:\nScenario: Your sibling consistently leaves the bathroom in a messy state after use.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-08-05T21:01:32+00:00', 'title': "John's Worksheets (PDF)", 'moddate': '2024-08-05T21:01:32+00:00', 'keywords': 'DAGMWkorcD0,BAGMWiBJdPI', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/FocusPlanWorksheet.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Mentalyc Inc\nADHD Focus Plan\nWorksheet\nCreated by www.mentalyc.com\nCOMMITMENT TO RELATIONSHIP \nRATING\nUsing this ADHD Focus Plan worksheet can help you with you manage your tasks,\nimprove focus, and enhance productivity. Edit the sheet to fit personal preferences\nand needs for the best results.\nStep 1: Define the task\nWrite one task you need to complete today\nTask Time Required\n1\n2\n3.\n4\n5\n6\nStep 2:  Break the task into smaller parts\nBreaking the task into smaller manageable ones can make it feel less tasking\nYOUR PARAGRAPH TEXT'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-08-05T21:01:32+00:00', 'title': "John's Worksheets (PDF)", 'moddate': '2024-08-05T21:01:32+00:00', 'keywords': 'DAGMWkorcD0,BAGMWiBJdPI', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/FocusPlanWorksheet.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='ADHD Focus Plan \nWorksheet\nRATING\nTime Activity Note\n9:00 AM\n10:00 AM\n11:00 AM\n12:00 PM\n1:00 PM\n2:00 PM\n3:00 PM\n4:00 PM\n5:00 PM\n6:00 PM\nYOUR PARAGRAPH TEXT\nMentalyc IncCreated by www.mentalyc.com\nCOMMITMENT TO RELATIONSHIP \nTime Activity Note\n8:00 AM\nYOUR PARAGRAPH TEXT\nStep 3:  Create a schedule\nSchedule the task for a specific time'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-08-05T21:01:32+00:00', 'title': "John's Worksheets (PDF)", 'moddate': '2024-08-05T21:01:32+00:00', 'keywords': 'DAGMWkorcD0,BAGMWiBJdPI', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/FocusPlanWorksheet.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='ADHD Focus Plan \nWorksheet\nRATING\nYOUR PARAGRAPH TEXT\nEliminate distractions Plan for unavoidable distractions\nMaterial and supplies Physical Preparation\nList the distractions you can\neliminate before starting\n1. Create “If then” plan for likely\ndistractions for Eg “If my\nfriend calls, then I will ask\nthem to call me in 20\nMinutes”\nList all the items you might\nneed\n1. List actions you will take to\nbe ready for the task\nStep 4:  Prepare for the Task\nList how you will get ready to work on the task\nStep 5:  Reflection\nList how you will get ready to work on the task\nWhat Went Well Today?\nChallenges Faced:\nAdjustments for Tomorrow\nCOMMITMENT TO RELATIONSHIP \nMentalyc IncCreated by www.mentalyc.com\nCOMMITMENT TO RELATIONSHIP'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-08-09T17:18:22+00:00', 'title': "John's Worksheets (PDF)", 'moddate': '2024-08-09T17:18:21+00:00', 'keywords': 'DAGMWkorcD0,BAGMWiBJdPI', 'author': 'Eseosa Osayimwen', 'source': '../data/pdf/ADHDWorksheet.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Mentalyc Inc\nRATING\nObservation Rarely Sometimes Often Always\n1 Often has difficulty sustaining attention in tasks\nor play activities.\n2\nFrequently makes careless mistakes in\nschoolwork, often seems not to listen when\nspoken to directly.\n3\nOften fails to follow through on instructions and\nfails to finish schoolwork, chores, or duties in the\nworkplace.\n4 Does the student benefit from a structured\nenvironment with clear expectations?\n5 Are instructions broken down into smaller, more\nmanageable steps?\n6 Is positive reinforcement used to encourage\ngood behavior?\n7 Is the student's seating arrangement conducive\nto minimizing distractions?\n8 Are visual reminders or cues used to help the\nstudent stay on task?\n9 Have you discussed the student's behavior and\nacademic performance with their parents?\n10 Do parents report similar behaviors at home?\nADHD Checklist For \nTeachers Worksheet\nCOMMITMENT TO RELATIONSHIP \nCreated by www.mentalyc.com\nCOMMITMENT TO RELATIONSHIP \nCollaboration with Support Staff\nHave you consulted with a school counselor, psychologist, or special education teacher\nabout this student? Yes No\nName Grade\nInstruction: Fill in student information (name, grade, date) Observe student behavior\nover several weeks")]
